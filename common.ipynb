# %%
subjects = ["Fizyka", "Prawo", "Literatura", "Filozofia", "Językoznawstwo", "Geografia", "Historia", "Geografia", "Matematyka", "Prawo", "Prawo", "Prawo", "Socjologia", "Chemia", "Literaturoznawstwo", "Socjologia", "Geografia", "Historia", "Fizyka", "Prawo", "Ekonomia", "Geografia", "Geografia", "Demografia", "Prawo", "Biologia", "Literaturoznawstwo", "Ekonomia", "Prawo", "Archeologia", "Ekonomia", "Literaturoznawstwo", "Prawo", "Matematyka", "Historia", "Językoznawstwo", "Prawo", "Ekonomia", "Fizyka", "Geografia", "Translatoryka", "Historia", "Ekonomia", "Ekonomia", "Filozofia", "Fizyka", "Historia", "Językoznawstwo", "Filozofia", "Matematyka", "Polityka", "Historia", "Ekonomia", "Ekonomia", "Literaturoznawstwo", "Językoznawstwo", "Ekonomia", "Biologia", "Historia", "Historia idei", "Edukacja", "Teatr", "Film", "Językoznawstwo", "Chemia", "Ekonomia", "Ekonomia", "Geografia", "Ekonomia", "Ekonomia", "Chemia", "Literaturoznawstwo", "Historia", "Polityka", "Historia", "Chemia", "Polityka", "Prawo", "Polityka", "Chemia", "Geografia", "Filozofia", "Biologia", "Matematyka", "Matematyka", "Prawo", "Literatura", "Film", "Chemia", "Literatura", "Prawo", "Historia", "Historia", "Teologia", "Filozofia", "Chemia", "Ekonomia", "Polityka", "Filozofia", "Polityka", "Prawo", "Biologia", "Prawo", "Prawo"]

i=0
for subject in subjects:
    i += 1
    print(f"{subject.lower()}")
# Out:
# fizyka
# prawo
# literatura
# filozofia
# językoznawstwo
# geografia
# historia
# geografia
# matematyka
# prawo
# prawo
# prawo
# socjologia
# chemia
# literaturoznawstwo
# socjologia
# geografia
# historia
# fizyka
# prawo
# ekonomia
# geografia
# geografia
# demografia
# prawo
# biologia
# literaturoznawstwo
# ekonomia
# prawo
# archeologia
# ekonomia
# literaturoznawstwo
# prawo
# matematyka
# historia
# językoznawstwo
# prawo
# ekonomia
# fizyka
# geografia
# translatoryka
# historia
# ekonomia
# ekonomia
# filozofia
# fizyka
# historia
# językoznawstwo
# filozofia
# matematyka
# polityka
# historia
# ekonomia
# ekonomia
# literaturoznawstwo
# językoznawstwo
# ekonomia
# biologia
# historia
# historia idei
# edukacja
# teatr
# film
# językoznawstwo
# chemia
# ekonomia
# ekonomia
# geografia
# ekonomia
# ekonomia
# chemia
# literaturoznawstwo
# historia
# polityka
# historia
# chemia
# polityka
# prawo
# polityka
# chemia
# geografia
# filozofia
# biologia
# matematyka
# ...

# %%
countries2 = [
    # {"name":"", "country":"", "local_wikis":"",},
    {"name": "Albania",                "country": "wd:Q222",    "local_wikis": ["<https://sq.wikipedia.org/>"]},
    {"name": "Armenia",                "country": "wd:Q399",    "local_wikis": ["<https://hy.wikipedia.org/>", "<https://hyw.wikipedia.org/>"]},
    {"name": "Austria",                "country": "wd:Q40",     "local_wikis": ["<https://de.wikipedia.org/>"]},
    {"name": "Azerbejdżan",            "country": "wd:Q227",    "local_wikis": ["<https://az.wikipedia.org/>"]},
    {"name": "Białoruś",               "country": "wd:Q184",    "local_wikis": ["<https://be.wikipedia.org/>", "<https://be-tarask.wikipedia.org/>"]},
    {"name": "Bośnia i Hercegowina",   "country": "wd:Q225",    "local_wikis": ["<https://bs.wikipedia.org/>"]},
    {"name": "Chorwacja",              "country": "wd:Q224",    "local_wikis": ["<https://hr.wikipedia.org/>"]},
    {"name": "Grecja",                 "country": "wd:Q41",     "local_wikis": ["<https://el.wikipedia.org/>"]},
    {"name": "Gruzja",                 "country": "wd:Q230",    "local_wikis": ["<https://ka.wikipedia.org/>"]},
    {"name": "Kazachstan",             "country": "wd:Q232",    "local_wikis": ["<https://kk.wikipedia.org/>"]},
    {"name": "Kosowo",                 "country": "wd:Q1246",   "local_wikis": ["<https://sq.wikipedia.org/>"]},
    {"name": "Litwa",                  "country": "wd:Q37",     "local_wikis": ["<https://lt.wikipedia.org/>"]},
    {"name": "Łotwa",                  "country": "wd:Q211",    "local_wikis": ["<https://lv.wikipedia.org/>"]},
    {"name": "Macedonia Północna",     "country": "wd:Q221",    "local_wikis": ["<https://mk.wikipedia.org/>"]},
    {"name": "Malta",                  "country": "wd:Q233",    "local_wikis": ["<https://mt.wikipedia.org/>"]},
    {"name": "Rosja",                  "country": "wd:Q159",    "local_wikis": ["<https://ru.wikipedia.org/>"]},
    {"name": "Rumunia",                "country": "wd:Q218",    "local_wikis": ["<https://ro.wikipedia.org/>"]},
    {"name": "Serbia",                 "country": "wd:Q403",    "local_wikis": ["<https://sr.wikipedia.org/>"]},
    {"name": "Słowacja",               "country": "wd:Q214",    "local_wikis": ["<https://sk.wikipedia.org/>"]},
    {"name": "Słowenia",               "country": "wd:Q215",    "local_wikis": ["<https://sl.wikipedia.org/>"]},
    {"name": "Ukraina",                "country": "wd:Q212",    "local_wikis": ["<https://uk.wikipedia.org/>"]},
    {"name": "Węgry",                  "country": "wd:Q28",     "local_wikis": ["<https://hu.wikipedia.org/>"]},
    {"name": "Baszkortostan",          "country": "wd:Q5710",   "local_wikis": ["<https://ba.wikipedia.org/>"]},
    {"name": "Czuwaszja",              "country": "wd:Q5466",   "local_wikis": ["<https://cv.wikipedia.org/>"]},
    {"name": "Republika Serbska",      "country": "wd:Q11196",  "local_wikis": ["<https://sr.wikipedia.org/>"]},
    {"name": "Ruś Nowogrodzka",        "country": "wd:Q9324216","local_wikis": []},
    {"name": "Arumuni",                "country": "wd:Q201111", "local_wikis": ["<https://roa-rup.wikipedia.org/>"]},
    {"name": "Tatarzy",                "country": "wd:Q35565",  "local_wikis": ["<https://tt.wikipedia.org/>"]},
    {"name": "Tatarzy krymscy",        "country": "wd:Q117458", "local_wikis": ["<https://crh.wikipedia.org/>"]},

    {"name":"Polska", "country": "wd:Q36", "local_wikis":["<https://pl.wikipedia.org/>"], },
]

countries = [
        {"name": "Kosowo",                 "country": "wd:Q1246",   "local_wikis": ["<https://sq.wikipedia.org/>"]},
    {"name": "Litwa",                  "country": "wd:Q37",     "local_wikis": ["<https://lt.wikipedia.org/>"]},
    {"name": "Łotwa",                  "country": "wd:Q211",    "local_wikis": ["<https://lv.wikipedia.org/>"]},
    {"name": "Macedonia Północna",     "country": "wd:Q221",    "local_wikis": ["<https://mk.wikipedia.org/>"]},
    {"name": "Malta",                  "country": "wd:Q233",    "local_wikis": ["<https://mt.wikipedia.org/>"]},
    {"name": "Rosja",                  "country": "wd:Q159",    "local_wikis": ["<https://ru.wikipedia.org/>"]},
]

for c in countries:
    print(c["country"])
# Out:
# wd:Q222
# wd:Q399
# wd:Q40
# wd:Q227
# wd:Q184
# wd:Q225
# wd:Q224
# wd:Q41
# wd:Q230
# wd:Q232
# wd:Q1246
# wd:Q37
# wd:Q211
# wd:Q221
# wd:Q233
# wd:Q159
# wd:Q218
# wd:Q403
# wd:Q214
# wd:Q215
# wd:Q212
# wd:Q28
# wd:Q5710
# wd:Q5466
# wd:Q11196
# wd:Q9324216
# wd:Q201111
# wd:Q35565
# wd:Q117458
# wd:Q36

# %%
data = [{'name': 'Albania', 'population': '2811655.0', 'area': '28748.0', 'pl_wiki': '9278', 'en_wiki': '20790', 'local_wikis': 31156}, {'name': 'Armenia', 'population': '2930450.0', 'area': '29743.423459', 'pl_wiki': '5288', 'en_wiki': '16524', 'local_wikis': 2830}, {'name': 'Austria', 'population': '8979894.0', 'area': '83878.99', 'pl_wiki': '23172', 'en_wiki': '64754', 'local_wikis': 190456}, {'name': 'Azerbejdżan', 'population': '10180770.0', 'area': '86600.0', 'pl_wiki': '5098', 'en_wiki': '27460', 'local_wikis': 39664}, {'name': 'Białoruś', 'population': '9109280.0', 'area': '207596.76', 'pl_wiki': '45628', 'en_wiki': '19906', 'local_wikis': 55464}, {'name': 'Bośnia i Hercegowina', 'population': '3816459.0', 'area': '51197.0', 'pl_wiki': '16270', 'en_wiki': '25210', 'local_wikis': 22664}, {'name': 'Chorwacja', 'population': '3871833.0', 'area': '56594.0', 'pl_wiki': '22820', 'en_wiki': '36440', 'local_wikis': 52398}, {'name': 'Grecja', 'population': '10482487.0', 'area': '131957.0', 'pl_wiki': '11610', 'en_wiki': '54400', 'local_wikis': 97526}, {'name': 'Gruzja', 'population': '3717100.0', 'area': '69700.0', 'pl_wiki': '6128', 'en_wiki': '13730', 'local_wikis': 32132}, {'name': 'Kazachstan', 'population': '20139914.0', 'area': '2724900.0', 'pl_wiki': '6654', 'en_wiki': '16242', 'local_wikis': 0}, {'name': 'Kosowo', 'population': '1586659.0', 'area': '10909.0', 'pl_wiki': None, 'en_wiki': None, 'local_wikis': 0}, {'name': 'Litwa', 'population': '2860002.0', 'area': '65300.0', 'pl_wiki': None, 'en_wiki': None, 'local_wikis': 0}, {'name': 'Łotwa', 'population': '1856932.0', 'area': '62226.85', 'pl_wiki': None, 'en_wiki': None,
data_3 = [{'name': 'Estonia', 'population': '1369995.0', 'area': '45335.0', 'pl_wiki': '16950', 'en_wiki': '38892', 'local_wikis': 125262}, {'name': 'Uzbekistan', 'population': '34915100.0', 'area': '448978.0', 'pl_wiki': '3096', 'en_wiki': '10574', 'local_wikis': 28484}, {'name': 'Polska', 'population': '37563071.0', 'area': '312683.0', 'pl_wiki': '555278', 'en_wiki': '194110', 'local_wikis': 555278}]

data_4 = [{'name': 'Cypr', 'population': '1344976.0', 'area': '9242.45', 'pl_wiki': '3690', 'en_wiki': '10336', 'local_wikis': 8820}, {'name': 'Erzianie', 'population': None, 'area': None, 'pl_wiki': '4', 'en_wiki': '6', 'local_wikis': 18}, {'name': 'Esperanto', 'population': None, 'area': None, 'pl_wiki': '1128', 'en_wiki': '2004', 'local_wikis': 16186}]


int_fields = ['population', 'area', 'pl_wiki', 'en_wiki', 'local_wikis']

for row in data_4:
    for field in int_fields:
        if row[field] is not None:
            row[field] = int(float(row[field]))
    print(f"[\"{row['name']}\", {row['population']}, {row['area']}, {row['pl_wiki']},{row['en_wiki']}, {row['local_wikis']}],")
# Out:
# ["Cypr", 1344976, 9242, 3690,10336, 8820],
# ["Erzianie", None, None, 4,6, 18],
# ["Esperanto", None, None, 1128,2004, 16186],

# %%
data = [{'name': 'Kosowo', 'population': '1586659.0', 'area': '10909.0', 'pl_wiki': '2080', 'en_wiki': '5374', 'local_wikis': 10842}, {'name': 'Litwa', 'population': '2860002.0', 'area': '65300.0', 'pl_wiki': '17942', 'en_wiki': '23538', 'local_wikis': 111226}, {'name': 'Łotwa', 'population': '1856932.0', 'area': '62226.85', 'pl_wiki': '8458', 'en_wiki': '20108', 'local_wikis': 65302}, {'name': 'Macedonia Północna', 'population': '1836713.0', 'area': '25713.0', 'pl_wiki': '4488', 'en_wiki': '11728', 'local_wikis': 33204}, {'name': 'Malta', 'population': '553214.0', 'area': '316.0', 'pl_wiki': '4292', 'en_wiki': '11866', 'local_wikis': 2866}, {'name': 'Rosja', 'population': '146119928.0', 'area': '17075400.0', 'pl_wiki': '73852', 'en_wiki': '180016', 'local_wikis': 780936}]

int_fields = ['population', 'area', 'pl_wiki', 'en_wiki', 'local_wikis']

for row in data:
    for field in int_fields:
        if row[field] is not None:
            row[field] = int(float(row[field]))
    print(f"[\"{row['name']}\", {row['population']}, {row['area']}, {row['pl_wiki']},{row['en_wiki']}, {row['local_wikis']}],")
# Out:
# ["Kosowo", 1586659, 10909, 2080,5374, 10842],
# ["Litwa", 2860002, 65300, 17942,23538, 111226],
# ["Łotwa", 1856932, 62226, 8458,20108, 65302],
# ["Macedonia Północna", 1836713, 25713, 4488,11728, 33204],
# ["Malta", 553214, 316, 4292,11866, 2866],
# ["Rosja", 146119928, 17075400, 73852,180016, 780936],

# %%
countries = [
    # {"name":"", "country":"", "local_wikis":"",},
    {"name": "Albania",                "country": "wd:Q222",    "local_wikis": ["<https://sq.wikipedia.org/>"]},
    {"name": "Armenia",                "country": "wd:Q399",    "local_wikis": ["<https://hy.wikipedia.org/>", "<https://hyw.wikipedia.org/>"]},
    {"name": "j. arumuński",                "country": "wd:Q201111", "local_wikis": ["<https://roa-rup.wikipedia.org/>"]},
    {"name": "Austria",                "country": "wd:Q40",     "local_wikis": ["<https://de.wikipedia.org/>"]},
    {"name": "Azerbejdżan",            "country": "wd:Q227",    "local_wikis": ["<https://az.wikipedia.org/>"]},
    {"name": "Baszkortostan",          "country": "wd:Q5710",   "local_wikis": ["<https://ba.wikipedia.org/>"]},
    {"name": "Białoruś",               "country": "wd:Q184",    "local_wikis": ["<https://be.wikipedia.org/>", "<https://be-tarask.wikipedia.org/>"]},
    {"name": "Bośnia i Hercegowina",   "country": "wd:Q225",    "local_wikis": ["<https://bs.wikipedia.org/>"]},
    {"name": "Bułgaria",   "country": "wd:Q219",    "local_wikis": ["<https://bg.wikipedia.org/>"]},
    {"name": "Czuwaszja",              "country": "wd:Q5466",   "local_wikis": ["<https://cv.wikipedia.org/>"]},
    {"name": "Półwysep Krymski",   "country": "wd:Q7835",    "local_wikis": []},
    {"name": "Karaimi",              "country": "wd:Q36",   "local_wikis": []},
    {"name": "Tatarzy krymscy",        "country": "wd:Q117458", "local_wikis": ["<https://crh.wikipedia.org/>"]},
    {"name": "Chorwacja",              "country": "wd:Q224",    "local_wikis": ["<https://hr.wikipedia.org/>"]},
    {"name": "Czechy",              "country": "wd:Q213",    "local_wikis": ["<https://cs.wikipedia.org/>"]},
    {"name": "Estonia",              "country": "wd:191",    "local_wikis": ["<https://et.wikipedia.org/>"]},
    {"name": "Grecja",                 "country": "wd:Q41",     "local_wikis": ["<https://el.wikipedia.org/>"]},
    {"name": "Węgry",                  "country": "wd:Q28",     "local_wikis": ["<https://hu.wikipedia.org/>"]},
    {"name": "Iran",                  "country": "wd:Q794",     "local_wikis": ["<https://fa.wikipedia.org/>"]},
    {"name": "Kazachstan",             "country": "wd:Q232",    "local_wikis": ["<https://kk.wikipedia.org/>"]},
    {"name": "Kosowo",                 "country": "wd:Q1246",   "local_wikis": ["<https://sq.wikipedia.org/>"]},
    {"name": "Krymczacy",                 "country": "wd:Q36",   "local_wikis": []},
    {"name": "Łotwa",                  "country": "wd:Q211",    "local_wikis": ["<https://lv.wikipedia.org/>"]},
    {"name": "Litwa",                  "country": "wd:Q37",     "local_wikis": ["<https://lt.wikipedia.org/>"]},
    {"name": "Malta",                  "country": "wd:Q233",    "local_wikis": ["<https://mt.wikipedia.org/>"]},
    {"name": "Czarnogóra",     "country": "wd:Q236",    "local_wikis": []},
    {"name": "Macedonia Północna",     "country": "wd:Q221",    "local_wikis": ["<https://mk.wikipedia.org/>"]},
    {"name": "Ruś Nowogrodzka",        "country": "wd:Q9324216","local_wikis": []},
    {"name": "Republika Serbska",      "country": "wd:Q11196",    "local_wikis": ["<https://sr.wikipedia.org/>"]},
    {"name": "Rumunia i Mołdawia",     "country": "wd:Q218",    "local_wikis": ["<https://ro.wikipedia.org/>"]},
    {"name": "Romowie",                  "country": "wd:Q36",    "local_wikis": ["<https://rmy.wikipedia.org/>"]},
    {"name": "Rosja",                  "country": "wd:Q159",    "local_wikis": ["<https://ru.wikipedia.org/>"]},
    {"name": "Serbia",                 "country": "wd:Q403",    "local_wikis": ["<https://sr.wikipedia.org/>"]},
    {"name": "Słowacja",               "country": "wd:Q214",    "local_wikis": ["<https://sk.wikipedia.org/>"]},
    {"name": "Słowenia",               "country": "wd:Q215",    "local_wikis": ["<https://sl.wikipedia.org/>"]},
    {"name": "Języki łużyckie",       "country": "wd:Q146521",    "local_wikis": []},
    {"name": "Tatarzy", "country": "wd:Q35565", "local_wikis": ["<https://tt.wikipedia.org/>"]},
    {"name": "Turcja", "country": "wd:Q43", "local_wikis": ["<https://tr.wikipedia.org/>"]},
    {"name": "Ukraina",                "country": "wd:Q212",    "local_wikis": ["<https://uk.wikipedia.org/>"]},
    {"name": "Võro",                "country": "wd:Q188076",    "local_wikis": ["<https://fiu-vro.wikipedia.org/>"]},
    {"name": "J. zachodnioormiański",     "country": "wd:Q36",    "local_wikis": ["<https://hyw.wikipedia.org/>"]},
    {"name": "Gruzja",                 "country": "wd:Q230",    "local_wikis": ["<https://ka.wikipedia.org/>"]},
    {"name": "Kirgistan",                 "country": "wd:Q813",    "local_wikis": ["<https://ky.wikipedia.org/>"]},
    {"name": "Maroko",                 "country": "wd:Q1028",    "local_wikis": ["<https://ar.wikipedia.org/>"]},
    {"name": "Jakucja",                 "country": "wd:Q6605",    "local_wikis": ["<https://sah.wikipedia.org/>"]},
    {"name": "Tadżykistan",                 "country": "wd:Q863",    "local_wikis": ["<https://tg.wikipedia.org/>"]},
    {"name": "Uzbekistan",                 "country": "wd:Q265",    "local_wikis": ["<https://uz.wikipedia.org/>"]},

    {"name":"Polska", "country": "wd:Q36", "local_wikis":["<https://pl.wikipedia.org/>"], },
]
for c in countries:
    print(c["country"])
# Out:
# wd:Q222
# wd:Q399
# wd:Q201111
# wd:Q40
# wd:Q227
# wd:Q5710
# wd:Q184
# wd:Q225
# wd:Q219
# wd:Q5466
# wd:Q7835
# wd:Q36
# wd:Q117458
# wd:Q224
# wd:Q213
# wd:191
# wd:Q41
# wd:Q28
# wd:Q794
# wd:Q232
# wd:Q1246
# wd:Q36
# wd:Q211
# wd:Q37
# wd:Q233
# wd:Q236
# wd:Q221
# wd:Q9324216
# wd:Q11196
# wd:Q218
# wd:Q36
# wd:Q159
# wd:Q403
# wd:Q214
# wd:Q215
# wd:Q146521
# wd:Q35565
# wd:Q43
# wd:Q212
# wd:Q188076
# wd:Q36
# wd:Q230
# wd:Q813
# wd:Q1028
# wd:Q6605
# wd:Q863
# wd:Q265
# wd:Q36
